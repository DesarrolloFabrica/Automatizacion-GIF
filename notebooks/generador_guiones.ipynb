# %% [markdown]
# # Generador de guiones académicos
#
# Flujo para cargar un sílabo, revisar los cinco temas detectados y generar los documentos base en Word.

# %% [markdown]
# ## 1. Instalación
#
# Ejecuta esta celda una vez si el entorno no tiene las dependencias.

# %%
import sys
import subprocess

print('Python del kernel:', sys.executable)
subprocess.check_call([
    sys.executable,
    '-m',
    'pip',
    'install',
    'python-docx',
    'pypdf',
    'openai',
    'python-dotenv',
])
# Out:
# Python del kernel: C:\Users\DELL\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe
# 0

# %% [markdown]
# ## 2. Configuración
#
# La API key debe estar en la variable de entorno `OPENAI_API_KEY`. Evita escribirla directamente en el notebook.

# %%
import os
from pathlib import Path

BASE_DIR = Path('..').resolve()
SYLLABUS = BASE_DIR / 'Syllabus ejemplo.docx'
OUTPUT_DIR = BASE_DIR / 'outputs'
MODEL = os.getenv('OPENAI_MODEL', 'gpt-4o')

# En PowerShell, configura antes de abrir Jupyter:
# $env:OPENAI_API_KEY="TU_API_KEY"

# %% [markdown]
# ## 3. Revisar plan detectado sin consumir API

# %%
import sys
sys.path.append(str(BASE_DIR))

print('BASE_DIR:', BASE_DIR)
print('SYLLABUS existe:', SYLLABUS.exists(), SYLLABUS)

from generate_guiones import extract_course_plan

plan = extract_course_plan(SYLLABUS)
plan
# Out:
# BASE_DIR: C:\Users\DELL\Documents\Automatizacion guiones
# SYLLABUS existe: True C:\Users\DELL\Documents\Automatizacion guiones\Syllabus ejemplo.pdf
# CoursePlan(asignatura='Formulación y Evaluación de Proyectos Internacionales', programa='NEGOCIOS INTERNACIONALES', escuela='ESCUELA DE TRANSFORMACIÓN EMPRESARIAL', semestre='(Nivel) Semestre N°8', ciclo='', modalidad='Presencial y Virtual', creditos='Acompañamiento', competencias='organizaciones que buscan expandirse internacionalmente y generar un impacto positivo en diferentes mercados. Además, el curso incluirá contenidos clave como el marco lógico, que permitirá a los estudiantes estructurar sus proyectos de manera coherente y efectiva. Se abordará la viabilidad del mercado internacional, donde se analizarán factores que influyen en la aceptación de productos o servicios en diferentes contextos culturales y económicos. La viabilidad técnica será otro aspecto esencial a estudiar, evaluando la capacidad de implementar proyectos con los recursos disponibles. Asimismo, se profundizará en la viabilidad financiera del proyecto internacional, proporcionando herramientas para determinar su rentabilidad y sostenibilidad a largo plazo. Finalmente, se enseñará a realizar una evaluación completa del proyecto internacional, lo que permitirá a los estudiantes medir su impacto y efectividad, asegurando así una gestión estratégica en el ámbito global. En consecuencia, los estudiantes desarrollarán competencias que les permita dirigir las fases de preinversión, desde el perfil hasta la viabilidad, para evaluar la factibilidad de las alternativas de inversión en proyectos internacionales. Este curso contr ibuirá al resultado de aprendizaje relacionado con la gerencia del plan de negocios internacional de la organización, con una estrategia integral de mercadeo, para estructurar una posición competitiva en el mercado global. 3. ARTICULACIÓN CON PROYECTO DE INVESTIGACIÓN Y/O EXTENSIÓN Y PROYECCIÓN SOCIAL - En cuanto a la articulación con la investigación, con la estrategia didáctica Resumen Analítico de Estudio- RAE y el Seminario Alemán, se contará con elementos de juicio para fortalecer el marco teórico del proyecto de grado del estudiante. Lo anterior, en razón que en la revisión de la literatura disponible sobre el tema de interés del futuro egresado permite conocer: (a) recomendaciones futuras sugeridas por los investigadores en sus estudios; (b) sugerencias documentadas sobre las implicaciones prácticas requeridas para el trabajo de grado; además, (c) nuevas formas de abordar un tema que incentiven la realización del proyecto de grado. - En relación con la extensión, la estrategia didáctica taller aplicado, tiene como propósito que los estudiantes elaboren una propuesta integral para incorporar a una alternativa válida de intervención o cursos alternativos de acción, para buscar respuesta a una oportunidad de mejora susceptible de ser compatible con los negocios internacionales , de acuerdo con los elementos teóricos y conceptuales desarrollados en el curso. PAGINA 3 Formato Elaboración de Syllabus Proceso: Vicerrectoría Académica Área: Gestión de Aseguramiento Académico Código: ASA-FOR-001 Versión: 02 Elaboró: Especialista en Desarrollo de Producto – Coordinación de Autoevaluación y Acreditación Revisó: Coordinación de Autoevaluación y Acreditación - Dirección de Calidad Institucional Aprobó: Dirección de Calidad Institucional – Vicerrectoría Académica 4. ELEMENTOS DE LA MACROCOMPETENCIA Y ARTICULACIÓN CON EL RESULTADO DE APRENDIZAJE DEL PROGRAMA', resultados_aprendizaje='Competencias Resultados De Aprendizaje Dirige las fases de preinversión, desde el perfil hasta la viabilidad, para evaluar la factibilidad de las alternativas de inversión en proyectos internacionales. Gerencia el plan de negocios internacional de la organización, con una estrategia integral de mercadeo, para estructurar una posición competitiva en el mercado global.', pregunta_problema='¿Cómo pueden las empresas evaluar la viabilidad de sus proyectos internacionales utilizando las fases de preinversión para asegurar una posición competitiva en el mercado global?', t ...

# %% [markdown]
# ## 4. Generar documentos
#
# Esta celda llama a la API y puede tardar varios minutos porque genera cinco documentos largos.

# %%
import subprocess

cmd = [
    sys.executable,
    str(BASE_DIR / 'generate_guiones.py'),
    '--syllabus', str(SYLLABUS),
    '--output-dir', str(OUTPUT_DIR),
    '--model', MODEL,
]

subprocess.run(cmd, check=True)
# Out:
# CompletedProcess(args=['C:\\Users\\DELL\\AppData\\Local\\Microsoft\\WindowsApps\\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\\python.exe', 'C:\\Users\\DELL\\Documents\\Automatizacion guiones\\generate_guiones.py', '--syllabus', 'C:\\Users\\DELL\\Documents\\Automatizacion guiones\\Syllabus ejemplo.pdf', '--output-dir', 'C:\\Users\\DELL\\Documents\\Automatizacion guiones\\outputs', '--model', 'gpt-4o'], returncode=0)
